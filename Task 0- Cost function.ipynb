# %%
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd
import seaborn as sns
import statsmodels.api as smi
import matplotlib as mpl
import statsmodels as sm

# %%
import os
os.chdir('C:\\Users\\7 Computer home\\Desktop\\Data-science\\Golearn')
os.getcwd()
# Out:
# 'C:\\Users\\7 Computer home\\Desktop\\Data-science\\Golearn'

# %%
data1 = pd.read_csv('Book1.csv')

# %%
data1
# Out:
#   experience  test_score(out of 10)  interview_score(out of 10)  salary($)
# 0        NaN                    8.0                           9      50000
# 1        NaN                    8.0                           6      45000
# 2       five                    6.0                           7      60000
# 3        two                   10.0                          10      65000
# 4      seven                    9.0                           6      70000
# 5      three                    7.0                          10      62000
# 6        ten                    NaN                           7      72000
# 7     eleven                    7.0                           8      80000

# %%
ex_mapping = {'five ' : 5, 'two' : 2, 'seven' : 7, 'three' : 3, 'ten' : 1, 'eleven' : 11 }

# %%
data1['experience'] = data1['experience'].map(ex_mapping)
data1
# Out:
#    experience  test_score(out of 10)  interview_score(out of 10)  salary($)
# 0         NaN                    8.0                           9      50000
# 1         NaN                    8.0                           6      45000
# 2         NaN                    6.0                           7      60000
# 3         2.0                   10.0                          10      65000
# 4         7.0                    9.0                           6      70000
# 5         3.0                    7.0                          10      62000
# 6         1.0                    NaN                           7      72000
# 7        11.0                    7.0                           8      80000

# %%
data1.fillna(round(data1.mean()), inplace=True)

# %%
data1
# Out:
#    experience  test_score(out of 10)  interview_score(out of 10)  salary($)
# 0         5.0                    8.0                           9      50000
# 1         5.0                    8.0                           6      45000
# 2         5.0                    6.0                           7      60000
# 3         2.0                   10.0                          10      65000
# 4         7.0                    9.0                           6      70000
# 5         3.0                    7.0                          10      62000
# 6         1.0                    8.0                           7      72000
# 7        11.0                    7.0                           8      80000

# %%
X = data1.drop(['salary($)'], axis = 1)
X
# Out:
#    experience  test_score(out of 10)  interview_score(out of 10)
# 0         5.0                    8.0                           9
# 1         5.0                    8.0                           6
# 2         5.0                    6.0                           7
# 3         2.0                   10.0                          10
# 4         7.0                    9.0                           6
# 5         3.0                    7.0                          10
# 6         1.0                    8.0                           7
# 7        11.0                    7.0                           8

# %%
y = data1['salary($)']
y
# Out:
# 0    50000
# 1    45000
# 2    60000
# 3    65000
# 4    70000
# 5    62000
# 6    72000
# 7    80000
# Name: salary($), dtype: int64

# %%
# imports
import tensorflow as tf
from tensorflow import keras
from keras.models import Sequential
from keras.layers import Dense
from keras.layers import Dropout
from sklearn.metrics import r2_score
import matplotlib.pyplot as plt
from tensorflow.keras.optimizers import Adam
import keras
from matplotlib import pyplot
from keras.callbacks import EarlyStopping
import pandas as pd 
from sklearn.preprocessing import LabelEncoder
from sklearn.model_selection import train_test_split
import numpy as np

# %%
model = Sequential()
model.add(Dense(16, activation="relu", input_dim=3))
#model.add(Dense(80, activation="relu"))
#model.add(Dense(30, activation="relu"))
# Since the regression is performed, a Dense layer containing a single neuron with a linear activation function.
# Typically ReLu-based activation are used but since it is performed regression, it is needed a linear activation.
model.add(Dense(1, activation="linear"))

# Compile model: The model is initialized with the Adam optimizer and then it is compiled.
model.compile(loss='mean_squared_error', optimizer=Adam(lr=1e-3, decay=1e-3 / 200))

# Patient early stopping
es = EarlyStopping(monitor='loss', mode='min', verbose=1, patience=200)

# Fit the model
history = model.fit(X, y, epochs=100, batch_size=100, verbose=2, callbacks=[es])
# Out:
# C:\Users\Public\anaconda3\lib\site-packages\keras\optimizer_v2\adam.py:105: UserWarning: The `lr` argument is deprecated, use `learning_rate` instead.
#   super(Adam, self).__init__(name, **kwargs)
# Epoch 1/100
# 1/1 - 0s - loss: 4084215808.0000 - 350ms/epoch - 350ms/step
# Epoch 2/100
# 1/1 - 0s - loss: 4084205312.0000 - 2ms/epoch - 2ms/step
# Epoch 3/100
# 1/1 - 0s - loss: 4084194816.0000 - 2ms/epoch - 2ms/step
# Epoch 4/100
# 1/1 - 0s - loss: 4084184064.0000 - 4ms/epoch - 4ms/step
# Epoch 5/100
# 1/1 - 0s - loss: 4084173312.0000 - 2ms/epoch - 2ms/step
# Epoch 6/100
# 1/1 - 0s - loss: 4084162816.0000 - 5ms/epoch - 5ms/step
# Epoch 7/100
# 1/1 - 0s - loss: 4084152320.0000 - 2ms/epoch - 2ms/step
# Epoch 8/100
# 1/1 - 0s - loss: 4084141568.0000 - 2ms/epoch - 2ms/step
# Epoch 9/100
# 1/1 - 0s - loss: 4084130304.0000 - 5ms/epoch - 5ms/step
# Epoch 10/100
# 1/1 - 0s - loss: 4084119808.0000 - 3ms/epoch - 3ms/step
# Epoch 11/100
# 1/1 - 0s - loss: 4084108800.0000 - 2ms/epoch - 2ms/step
# ...

# %%
y2 = np.log(y)
y2
# Out:
# 0    10.819778
# 1    10.714418
# 2    11.002100
# 3    11.082143
# 4    11.156251
# 5    11.034890
# 6    11.184421
# 7    11.289782
# Name: salary($), dtype: float64

# %%
model = Sequential()
model.add(Dense(16, activation="relu", input_dim=3))
#model.add(Dense(80, activation="relu"))
#model.add(Dense(30, activation="relu"))
# Since the regression is performed, a Dense layer containing a single neuron with a linear activation function.
# Typically ReLu-based activation are used but since it is performed regression, it is needed a linear activation.
model.add(Dense(1, activation="linear"))

# Compile model: The model is initialized with the Adam optimizer and then it is compiled.
model.compile(loss='mean_squared_error', optimizer=Adam(lr=1e-3, decay=1e-3 / 200))

# Patient early stopping
es = EarlyStopping(monitor='loss', mode='min', verbose=1, patience=50,min_delta = 0.01)

# Fit the model
history = model.fit(X, y2,validation_split=0.3, epochs=100000, batch_size=2, verbose=2, callbacks=[es])
# Out:
# C:\Users\Public\anaconda3\lib\site-packages\keras\optimizer_v2\adam.py:105: UserWarning: The `lr` argument is deprecated, use `learning_rate` instead.
#   super(Adam, self).__init__(name, **kwargs)
# Epoch 1/100000
# 3/3 - 1s - loss: 214.2953 - val_loss: 204.6669 - 719ms/epoch - 240ms/step
# Epoch 2/100000
# 3/3 - 0s - loss: 206.9469 - val_loss: 197.3430 - 43ms/epoch - 14ms/step
# Epoch 3/100000
# 3/3 - 0s - loss: 199.6049 - val_loss: 190.2430 - 38ms/epoch - 13ms/step
# Epoch 4/100000
# 3/3 - 0s - loss: 192.5621 - val_loss: 183.2666 - 55ms/epoch - 18ms/step
# Epoch 5/100000
# 3/3 - 0s - loss: 185.6489 - val_loss: 176.5154 - 38ms/epoch - 13ms/step
# Epoch 6/100000
# 3/3 - 0s - loss: 178.8123 - val_loss: 169.9735 - 37ms/epoch - 12ms/step
# Epoch 7/100000
# 3/3 - 0s - loss: 172.3742 - val_loss: 163.5672 - 35ms/epoch - 12ms/step
# Epoch 8/100000
# 3/3 - 0s - loss: 166.1433 - val_loss: 157.3138 - 35ms/epoch - 12ms/step
# Epoch 9/100000
# ...
